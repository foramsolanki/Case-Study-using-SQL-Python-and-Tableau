# %% [markdown]
# # Churn case. Part 2. Analysis of LTV

# %% [markdown]
# Lifetime value (LTV) is the total worth to a business of a customer over the while period of their relationship. It's an important metric as it costs less to keep existings customers than to acquire new ones, so the idea of increasing the value of your existig customers is a great way to drive growth.

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("churn.db")

# %%
df = pd.read_sql("select * from churn_all", conn)

# %%
df.head()
# Out:
#    CustomerID  Gender SeniorCitizen Partner Dependents       State   Latitude  \
# 0  3668-QPYBK    Male            No      No         No  California  33.964131
# 1  9237-HQITU  Female            No      No        Yes  California  34.059281
# 2  9305-CDSKC  Female            No      No        Yes  California  34.048013
# 3  7892-POOKP  Female            No     Yes        Yes  California  34.062125
# 4  0280-XJGEX    Male            No      No        Yes  California  34.039224
#
#     Longitude  ZipCode PhoneService  ... TechSupport StreamingTV  \
# 0 -118.272783    90003          Yes  ...          No          No
# 1 -118.307420    90005          Yes  ...          No          No
# 2 -118.293953    90006          Yes  ...          No         Yes
# 3 -118.315709    90010          Yes  ...         Yes         Yes
# 4 -118.266293    90015          Yes  ...          No         Yes
#
#   StreamingMovies Tenure        Contract              PaymentMethod  \
# 0              No      2  Month-to-month               Mailed check
# 1              No      2  Month-to-month           Electronic check
# 2             Yes      8  Month-to-month           Electronic check
# 3             Yes     28  Month-to-month           Electronic check
# 4             Yes     49  Month-to-month  Bank transfer (automatic)
#
#   PaperlessBilling MonthlyCharges  TotalCharges Churn
# 0              Yes          53.85        108.15   Yes
# 1              Yes          70.70        151.65   Yes
# 2              Yes          99.65        820.50   Yes
# 3              Yes         104.80       3046.05   Yes
# 4              Yes         103.70       5036.30   Yes
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 1. For those customers who unsubscribed the service, what was their average LTV? and how long did they usually stay in the service?

# %%
## Extract those who unsubscribed the serviced (Churn = Yes)

churn_df = pd.read_sql("select * from churn_all where Churn = 'Yes'", conn)

# %%
# Examine the distribution of TotalCharges
churn_df["TotalCharges"].describe()
# Out:
# count    1869.000000
# mean     1531.796094
# std      1890.822994
# min        18.850000
# 25%       134.500000
# 50%       703.550000
# 75%      2331.300000
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %% [markdown]
# We can see that around 20% of the TotalCharges are very high, so let's divide the data to see each distribution.

# %%
# Find the 80th percentile of the data in TotalCharges
churn_df.TotalCharges.quantile(0.8)
# Out:
# 2840.4100000000003

# %%
pd.read_sql("select * from churn_all where TotalCharges <= 2840.41", conn)
# Out:
#       CustomerID  Gender SeniorCitizen Partner Dependents       State  \
# 0     3668-QPYBK    Male            No      No         No  California
# 1     9237-HQITU  Female            No      No        Yes  California
# 2     9305-CDSKC  Female            No      No        Yes  California
# 3     4190-MFLUW  Female            No     Yes         No  California
# 4     8779-QRDMV    Male           Yes      No         No  California
# 5     1066-JKSGK    Male            No      No         No  California
# 6     8665-UTDHZ    Male            No     Yes         No  California
# 7     8773-HHUOZ  Female            No      No         No  California
# 8     6047-YHPVI    Male            No      No        Yes  California
# 9     8168-UQWWF  Female            No      No        Yes  California
# 10    7760-OYPDY  Female            No      No        Yes  California
# 11    9420-LOJKX  Female            No      No        Yes  California
# 12    7495-OOKFY  Female           Yes     Yes        Yes  California
# 10    33.987945 -118.370442    90056          Yes  ...                   No
# 11    33.921280 -118.274186    90061          Yes  ...                   No
# 12    34.044271 -118.185237    90063          Yes  ...                   No
# 13    34.108833 -118.229715    90065          Yes  ...                   No
# 14    34.063947 -118.383001    90211          Yes  ...                   No
# 15    33.978030 -118.217141    90255          Yes  ...                   No
# 16    33.923573 -118.200669    90262          Yes  ...                   No
# 17    33.977468 -118.445475    90292          Yes  ...                   No
# 18    33.956445 -118.358634    90301          Yes  ...  No internet service
# 19    33.936291 -118.332639    90303          Yes  ...                   No
# 20    33.976678 -118.065875    90606          Yes  ...                   No
# 21    33.940619 -117.951300    90631          Yes  ...                   No
# 22    33.989524 -118.089299    90660          Yes  ...                   No
# 23    33.391181 -118.421305    90704           No  ...                   No
# 24    33.798266 -118.300237    90710           No  ...                   No
# 25    33.840524 -118.148403    90712          Yes  ...                   No
# 26    33.794990 -118.065591    90720          Yes  ...                   No
# 27    33.736387 -118.284363    90731          Yes  ...                  Yes
# 28    33.822295 -118.264110    90745          Yes  ...                   No
# 29    33.783047 -118.148600    90804          Yes  ...                   No
# ...         ...         ...      ...          ...  ...                  ...
# 4709  32.774046 -117.142454    92108           No  ...                   No
# 4710  32.686740 -117.186612    92118          Yes  ...                   No
# 4711  32.807867 -117.060993    92120          Yes  ...                   No
# 4712  32.857230 -117.209774    92122           No  ...                   No
# 4713  32.827238 -117.089287    92124          Yes  ...                  Yes
# 4714  33.017518 -117.118456    92127          Yes  ...                  Yes
# 4715  33.000269 -117.072093    92128           No  ...                   No
# 4716  32.961064 -117.134917    92129           No  ...                  Yes
# 4717  32.677716 -117.047666    92139          Yes  ...                  Yes
# 4718  32.578103 -117.012975    92154          Yes  ...                   No
# 4719  33.762759 -116.324817    92211          Yes  ...  No internet service
# 4720  33.674583 -114.716120    92225          Yes  ...                   No
# 4721  33.039330 -115.191857    92227          Yes  ...                   No
# 4722  32.690654 -115.431225    92231          Yes  ...  No internet service
# 4723  33.680031 -116.171678    92236           No  ...                  Yes
# 4724  33.948558 -116.516976    92240          Yes  ...  No internet service
# 4725  33.345825 -115.596574    92257          Yes  ...                   No
# 4726  33.906496 -116.569499    92258          Yes  ...  No internet service
# 4727  33.694501 -116.412711    92260          Yes  ...  No internet service
# 4728  33.839989 -116.659215    92262          Yes  ...  No internet service
# 4729  33.763678 -116.429928    92270          Yes  ...                  Yes
# 4730  33.536040 -116.119222    92274          Yes  ...                  Yes
# 4731  33.849263 -116.382778    92276           No  ...                   No
# 4732  34.172110 -115.769773    92277          Yes  ...  No internet service
# 4733  33.036790 -115.605030    92281          Yes  ...                   No
# 4734  32.852947 -114.850784    92283          Yes  ...                   No
# 4735  34.159534 -116.425984    92284           No  ...                  Yes
# 4736  34.341737 -116.539416    92285          Yes  ...  No internet service
# 4737  34.667815 -117.536183    92301          Yes  ...                  Yes
# 4738  34.167800 -116.864330    92305           No  ...                   No
#
#               StreamingTV      StreamingMovies Tenure        Contract  \
# 0                      No                   No      2  Month-to-month
# 1                      No                   No      2  Month-to-month
# 2                     Yes                  Yes      8  Month-to-month
# 3                      No                   No     10  Month-to-month
# 4                      No                  Yes      1  Month-to-month
# 5     No internet service  No internet service      1  Month-to-month
# 6                      No                   No      1  Month-to-month
# 7                     Yes                  Yes     17  Month-to-month
# 8                      No                   No      5  Month-to-month
# 9                     Yes                  Yes     11  Month-to-month
# 10                    Yes                   No      2  Month-to-month
# 11                    Yes                  Yes     15  Month-to-month
# 12                     No                   No      8  Month-to-month
# 13                    Yes                  Yes     18  Month-to-month
# 14                    Yes                  Yes      9  Month-to-month
# 15                    Yes                   No      1  Month-to-month
# 16                     No                   No      7  Month-to-month
# 17                     No                   No     12  Month-to-month
# 18    No internet service  No internet service      5  Month-to-month
# 19                    Yes                  Yes     25  Month-to-month
# 20                    Yes                  Yes     10  Month-to-month
# 21                     No                   No      3  Month-to-month
# 22                     No                   No     27  Month-to-month
# 23                    Yes                  Yes     25  Month-to-month
# 24                     No                  Yes      1  Month-to-month
# 25                     No                   No      2  Month-to-month
# 26                     No                   No      1  Month-to-month
# 27                     No                  Yes      8  Month-to-month
# 28                     No                   No      1  Month-to-month
# 29                    Yes                  Yes      7  Month-to-month
# ...                   ...                  ...    ...             ...
# 4709                  Yes                   No     50        One year
# 4710                   No                   No     24        Two year
# 4711                   No                   No     24  Month-to-month
# 4712                   No                   No      1  Month-to-month
# 4713                  Yes                   No      8  Month-to-month
# 4714                   No                   No     23  Month-to-month
# 4715                   No                   No     31  Month-to-month
# 4716                   No                   No     37        One year
# 4717                  Yes                   No     23  Month-to-month
# 4718                  Yes                  Yes     20        One year
# 4719  No internet service  No internet service     43        One year
# 4720                   No                   No     27  Month-to-month
# 4721                   No                  Yes     13  Month-to-month
# 4722  No internet service  No internet service     67        One year
# 4723                   No                   No     26  Month-to-month
# 4724  No internet service  No internet service     23        One year
# 4725                   No                   No      1  Month-to-month
# 4726  No internet service  No internet service     51        Two year
# 4727  No internet service  No internet service     39        Two year
# 4728  No internet service  No internet service     12  Month-to-month
# 4729                   No                  Yes     18  Month-to-month
# 4730                  Yes                  Yes     13  Month-to-month
# 4731                  Yes                  Yes      6  Month-to-month
# 4732  No internet service  No internet service      2  Month-to-month
# 4733                   No                   No     38  Month-to-month
# 4734                  Yes                   No     19  Month-to-month
# 4735                  Yes                  Yes     12        One year
# 4736  No internet service  No internet service     72        Two year
# 4737                  Yes                  Yes     24        One year
# 4738                   No                   No     11  Month-to-month
#
#                   PaymentMethod PaperlessBilling MonthlyCharges  TotalCharges  \
# 0                  Mailed check              Yes          53.85        108.15
# 1              Electronic check              Yes          70.70        151.65
# 2              Electronic check              Yes          99.65        820.50
# 3       Credit card (automatic)               No          55.20        528.35
# 4              Electronic check              Yes          39.65         39.65
# 5                  Mailed check               No          20.15         20.15
# 6              Electronic check               No          30.20         30.20
# 7                  Mailed check              Yes          64.70       1093.10
# 8              Electronic check              Yes          69.70        316.90
# 9     Bank transfer (automatic)              Yes          97.85       1105.40
# 10             Electronic check              Yes          80.65        144.15
# 11      Credit card (automatic)              Yes          99.10       1426.40
# 12      Credit card (automatic)              Yes          80.65        633.30
# 13             Electronic check              Yes          95.45       1752.55
# 14             Electronic check               No          94.40        857.25
# 15             Electronic check              Yes          79.35         79.35
# 16    Bank transfer (automatic)              Yes          75.15        496.90
# 17             Electronic check              Yes          78.95        927.35
# 18                 Mailed check               No          21.05        113.85
# 19             Electronic check              Yes          98.50       2514.50
# 20             Electronic check              Yes         100.25       1064.65
# 21             Electronic check              Yes          74.40        229.55
# 22             Electronic check              Yes          78.05       2135.50
# 23      Credit card (automatic)              Yes          58.60       1502.65
# 24             Electronic check              Yes          35.45         35.45
# 25             Electronic check               No          44.35         81.25
# 26                 Mailed check              Yes          70.45         70.45
# 27             Electronic check               No          71.15        563.65
# 28             Electronic check              Yes          45.65         45.65
# 29                 Mailed check               No          95.00        655.50
# ...                         ...              ...            ...           ...
# 4709  Bank transfer (automatic)              Yes          43.05       2208.05
# 4710           Electronic check               No          64.35       1558.65
# 4711               Mailed check              Yes          49.70       1218.25
# 4712               Mailed check               No          24.20         24.20
# 4713           Electronic check              Yes          65.45        554.45
# 4714  Bank transfer (automatic)               No          83.20       2032.30
# 4715    Credit card (automatic)               No          25.00        789.20
# 4716           Electronic check              Yes          40.20       1525.35
# 4717    Credit card (automatic)              Yes          69.50       1652.10
# 4718  Bank transfer (automatic)               No          76.00       1588.75
# 4719  Bank transfer (automatic)              Yes          24.45        993.15
# 4720           Electronic check              Yes          76.10       2093.40
# 4721           Electronic check              Yes          80.50       1011.80
# 4722           Electronic check               No          20.55       1343.40
# 4723           Electronic check               No          35.75       1022.50
# 4724    Credit card (automatic)               No          19.30        486.20
# 4725           Electronic check               No          49.95         49.95
# 4726  Bank transfer (automatic)               No          20.65       1020.75
# 4727               Mailed check               No          20.15        826.00
# 4728           Electronic check              Yes          19.20        239.00
# 4729  Bank transfer (automatic)              Yes          95.05       1679.40
# 4730               Mailed check               No          73.35        931.55
# 4731           Electronic check              Yes          44.40        263.05
# 4732               Mailed check              Yes          20.05         39.25
# 4733    Credit card (automatic)              Yes          69.50       2625.25
# 4734  Bank transfer (automatic)              Yes          78.70       1495.10
# 4735           Electronic check               No          60.65        743.30
# 4736  Bank transfer (automatic)              Yes          21.15       1419.40
# 4737               Mailed check              Yes          84.80       1990.50
# 4738           Electronic check              Yes          29.60        346.45
#
#      Churn
# 0      Yes
# 1      Yes
# 2      Yes
# 3      Yes
# 4      Yes
# 5      Yes
# 6      Yes
# 7      Yes
# 8      Yes
# 9      Yes
# 10     Yes
# 11     Yes
# 12     Yes
# 13     Yes
# 14     Yes
# 15     Yes
# 16     Yes
# 17     Yes
# 18     Yes
# 19     Yes
# 20     Yes
# 21     Yes
# 22     Yes
# 23     Yes
# 24     Yes
# 25     Yes
# 26     Yes
# 27     Yes
# 28     Yes
# 29     Yes
# ...    ...
# 4709    No
# 4710    No
# 4711    No
# 4712    No
# 4713    No
# 4714    No
# 4715    No
# 4716    No
# 4717    No
# 4718    No
# 4719    No
# 4720    No
# 4721    No
# 4722    No
# 4723    No
# 4724    No
# 4725    No
# 4726    No
# 4727    No
# 4728    No
# 4729    No
# 4730    No
# 4731    No
# 4732    No
# 4733    No
# 4734    No
# 4735    No
# 4736    No
# 1865                   No                   No      9  Month-to-month
# 1866                   No                   No      1  Month-to-month
# 1868                   No                   No      4  Month-to-month
#
#                   PaymentMethod PaperlessBilling MonthlyCharges  TotalCharges  \
# 0                  Mailed check              Yes          53.85        108.15
# 1              Electronic check              Yes          70.70        151.65
# 2              Electronic check              Yes          99.65        820.50
# 5       Credit card (automatic)               No          55.20        528.35
# 6              Electronic check              Yes          39.65         39.65
# 7                  Mailed check               No          20.15         20.15
# 9              Electronic check               No          30.20         30.20
# 10                 Mailed check              Yes          64.70       1093.10
# 11             Electronic check              Yes          69.70        316.90
# 13    Bank transfer (automatic)              Yes          97.85       1105.40
# 14             Electronic check              Yes          80.65        144.15
# 15      Credit card (automatic)              Yes          99.10       1426.40
# 16      Credit card (automatic)              Yes          80.65        633.30
# 17             Electronic check              Yes          95.45       1752.55
# 18             Electronic check               No          94.40        857.25
# 19             Electronic check              Yes          79.35         79.35
# 20    Bank transfer (automatic)              Yes          75.15        496.90
# 21             Electronic check              Yes          78.95        927.35
# 22                 Mailed check               No          21.05        113.85
# 23             Electronic check              Yes          98.50       2514.50
# 27             Electronic check              Yes         100.25       1064.65
# 28             Electronic check              Yes          74.40        229.55
# 29             Electronic check              Yes          78.05       2135.50
# 30      Credit card (automatic)              Yes          58.60       1502.65
# 31             Electronic check              Yes          35.45         35.45
# 32             Electronic check               No          44.35         81.25
# 33                 Mailed check              Yes          70.45         70.45
# 34             Electronic check               No          71.15        563.65
# 35             Electronic check              Yes          45.65         45.65
# 36                 Mailed check               No          95.00        655.50
# ...                         ...              ...            ...           ...
# 1829  Bank transfer (automatic)              Yes          45.10         45.10
# 1831           Electronic check               No          55.35        449.75
# 1834           Electronic check              Yes          69.35         69.35
# 1836    Credit card (automatic)              Yes          75.15        216.75
# 1837           Electronic check              Yes          69.60         69.60
# 1838           Electronic check              Yes          80.15        385.00
# 1839  Bank transfer (automatic)               No          30.50         30.50
# 1842           Electronic check              Yes          82.00       1127.20
# 1843    Credit card (automatic)              Yes          75.40       1747.85
# 1844           Electronic check              Yes         101.25       2754.45
# 1845           Electronic check              Yes          89.50       2196.15
# 1846  Bank transfer (automatic)              Yes          74.40       1692.60
# 1847               Mailed check               No          20.50         20.50
# 1848           Electronic check              Yes          74.35        265.35
# 1849  Bank transfer (automatic)               No          99.75       1836.25
# 1851               Mailed check              Yes          39.00        679.85
# 1852    Credit card (automatic)              Yes          94.10       2804.45
# 1853  Bank transfer (automatic)               No          95.65        778.10
# 1855  Bank transfer (automatic)              Yes          66.50       2728.60
# 1856               Mailed check              Yes          35.45        106.85
# 1857               Mailed check              Yes          49.90        130.10
# 1859    Credit card (automatic)              Yes          75.05        256.25
# 1860           Electronic check              Yes          81.00       1917.10
# 1861           Electronic check              Yes          74.45         74.45
# 1862               Mailed check              Yes          60.40        272.15
# 1863               Mailed check              Yes          70.65         70.65
# 1864           Electronic check              Yes          59.80        727.80
# 1865  Bank transfer (automatic)              Yes          44.20        403.35
# 1866           Electronic check              Yes          75.75         75.75
# 1868               Mailed check              Yes          74.40        306.60
#
#      Churn
# 0      Yes
# 1      Yes
# 2      Yes
# 5      Yes
# 6      Yes
# 7      Yes
# 9      Yes
# 10     Yes
# 11     Yes
# 13     Yes
# 14     Yes
# 15     Yes
# 16     Yes
# 17     Yes
# 18     Yes
# 19     Yes
# 20     Yes
# 21     Yes
# 22     Yes
# 23     Yes
# 27     Yes
# 28     Yes
# 29     Yes
# 30     Yes
# 31     Yes
# 32     Yes
# 33     Yes
# 34     Yes
# 35     Yes
# 36     Yes
# ...    ...
# 1829   Yes
# 1831   Yes
# 1834   Yes
# 1836   Yes
# 1837   Yes
# 1838   Yes
# 1839   Yes
# 1842   Yes
# 1843   Yes
# 1844   Yes
# 1845   Yes
# 1846   Yes
# 1847   Yes
# 1848   Yes
# 1849   Yes
# 1851   Yes
# 1852   Yes
# 1853   Yes
# 1855   Yes
# 1856   Yes
# 1857   Yes
# 1859   Yes
# 1860   Yes
# 1861   Yes
# 1862   Yes
# 1863   Yes
# 1864   Yes
# 1865   Yes
# 1866   Yes
# 1868   Yes
#
# [1495 rows x 25 columns]

# %%
# Divide the data by the 80th percentile of the data from the TotalCharges variable
total_charges_under80 = churn_df.query("TotalCharges <= 2840.41")
total_charges_above80 = churn_df.query("TotalCharges > 2840.41")

# %%
# Show the distribution of people under the 80th percentile
total_charges_under80.TotalCharges.describe()
# Out:
# count    1495.000000
# mean      711.265819
# std       766.848197
# min        18.850000
# 25%        85.025000
# 50%       371.650000
# 75%      1128.225000
# max      2839.650000
# Name: TotalCharges, dtype: float64

# %%
# Show the distribution of people above the 80th percentile
total_charges_above80.TotalCharges.describe()
# Out:
# count     374.000000
# mean     4811.723262
# std      1436.724288
# min      2841.550000
# 25%      3522.462500
# 50%      4571.100000
# 75%      5891.212500
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
# Show the distribution of the tenure of people under the 80th percentile
total_charges_under80.Tenure.describe()
# Out:
# count    1495.000000
# mean        9.935117
# std        10.742349
# min         1.000000
# 25%         1.000000
# 50%         6.000000
# 75%        15.000000
# max        61.000000
# Name: Tenure, dtype: float64

# %%
# Show the distribution of the tenure of people above the 80th percentile
total_charges_above80.Tenure.describe()
# Out:
# count    374.000000
# mean      50.133690
# std       12.334841
# min       27.000000
# 25%       40.000000
# 50%       49.500000
# 75%       60.000000
# max       72.000000
# Name: Tenure, dtype: float64

# %% [markdown]
# The average LTV of the 80% of those who unsubscribed is \\$ 711, and their tenure is near 10 months. On the hand, the average LTV of the 20 % of those who unsubscribed is $ 4811, and their tenure is near 50 months.

# %% [markdown]
# ## 2. What kinds of services they subscribed when they were still a customer?

# %% [markdown]
# ### PhoneService

# %%
# under 80
pd.read_sql("select count(1) from churn_all where TotalCharges <= 2840.41 and Churn = 'Yes' group by PhoneService", conn)
# Out:
#    count(1)
# 0       161
# 1      1334

# %%
df["Gender"].value_counts() # example
# Out:
# Male      3549
# Female    3483
# Name: Gender, dtype: int64

# %%
# under 80
total_charges_under80.PhoneService.value_counts()
# Out:
# Yes    1334
# No      161
# Name: PhoneService, dtype: int64

# %%
# Example of shape
df.shape
# Out:
# (7032, 25)

# %%
# Under 80 (percentage)
total_charges_under80.PhoneService.value_counts() / total_charges_under80.shape[0]
# Out:
# Yes    0.892308
# No     0.107692
# Name: PhoneService, dtype: float64

# %%
# Above 80 (percentage)
total_charges_above80.PhoneService.value_counts() / total_charges_above80.shape[0]
# Out:
# Yes    0.975936
# No     0.024064
# Name: PhoneService, dtype: float64

# %% [markdown]
# For the top 20% (high LTV) only 2% of them didn't use the phone service. On the other hand, lower 80% (LTV) had around 11% of the people that didn't use the phone service. That is around 5 times more as the top 20%. Apparently if you are not subscribed to the phone service you are more likely to be in the bottom 80% of the LTV. We as a company can try to sell this service to more people.

# %% [markdown]
# ### MutipleLines

# %%
total_charges_under80_use_phone = total_charges_under80.query("PhoneService == 'Yes'")

total_charges_under80_use_phone.MultipleLines.value_counts() / total_charges_under80_use_phone.shape[0]
# Out:
# No     0.590705
# Yes    0.409295
# Name: MultipleLines, dtype: float64

# %%
total_charges_above80_use_phone = total_charges_above80.query("PhoneService == 'Yes'")

total_charges_above80_use_phone.MultipleLines.value_counts() / total_charges_above80_use_phone.shape[0]
# Out:
# Yes    0.832877
# No     0.167123
# Name: MultipleLines, dtype: float64

# %% [markdown]
# For the top 20% of LTV who used the phone service 84% of them used multiple lines, which is 2 times as much as the proportion of people in the low 80% LTV that is around 40%. Having multiple lines is going to get you closer to be in the top 20% of the LTV.

# %% [markdown]
# ### InternetService

# %%
# Under 80 (percentage)
total_charges_under80.InternetService.value_counts() / total_charges_under80.shape[0]
# Out:
# Fiber optic    0.640803
# DSL            0.283612
# No             0.075585
# Name: InternetService, dtype: float64

# %%
# Above 80 (percentage)
total_charges_above80.InternetService.value_counts() / total_charges_above80.shape[0]
# Out:
# Fiber optic    0.906417
# DSL            0.093583
# Name: InternetService, dtype: float64

# %% [markdown]
# All the people in the high 20% LTV used internet service. On the other hand 8% of the people in the low 80th percentile of the LTV did not have internet connection. Also, in the top 20% (high LTV) 90% of them had fiber optic, in comparison to only 64% in the low LTV. So as a company if we want to increase the LTV of customers, we should recommend using internet and Fiber Optic connection.

# %% [markdown]
# ### Other services

# %%
import numpy as np

# %%
total_charges_under80_use_internet = total_charges_under80.query('InternetService!="No"')
proportion_internet_sub_service_under80 = np.array([total_charges_under80_use_internet.query('OnlineSecurity=="Yes"').shape[0]/total_charges_under80_use_internet.shape[0],
total_charges_under80_use_internet.query('TechSupport=="Yes"').shape[0]/total_charges_under80_use_internet.shape[0],
total_charges_under80_use_internet.query('OnlineBackup=="Yes"').shape[0]/total_charges_under80_use_internet.shape[0],
total_charges_under80_use_internet.query('DeviceProtection=="Yes"').shape[0]/total_charges_under80_use_internet.shape[0],
total_charges_under80_use_internet.query('StreamingTV=="Yes"').shape[0]/total_charges_under80_use_internet.shape[0],
total_charges_under80_use_internet.query('StreamingMovies=="Yes"').shape[0]/total_charges_under80_use_internet.shape[0]])

# %%
proportion_internet_sub_service_under80
# Out:
# array([0.1316932 , 0.13603473, 0.22720695, 0.23516643, 0.37698987,
#        0.3813314 ])

# %%
total_charges_above80_use_internet = total_charges_above80.query('InternetService!="No"')
proportion_internet_sub_service_above80 = np.array([total_charges_above80_use_internet.query('OnlineSecurity=="Yes"').shape[0]/total_charges_above80_use_internet.shape[0],
total_charges_above80_use_internet.query('TechSupport=="Yes"').shape[0]/total_charges_above80_use_internet.shape[0],
total_charges_above80_use_internet.query('OnlineBackup=="Yes"').shape[0]/total_charges_above80_use_internet.shape[0],
total_charges_above80_use_internet.query('DeviceProtection=="Yes"').shape[0]/total_charges_above80_use_internet.shape[0],
total_charges_above80_use_internet.query('StreamingTV=="Yes"').shape[0]/total_charges_above80_use_internet.shape[0],
total_charges_above80_use_internet.query('StreamingMovies=="Yes"').shape[0]/total_charges_above80_use_internet.shape[0]])

# %%
proportion_internet_sub_service_above80
# Out:
# array([0.30213904, 0.32620321, 0.55882353, 0.58823529, 0.78342246,
#        0.77807487])

# %% [markdown]
# In the top 20% LTV, both streaming movies and streaming tv percentages are around 80%, in comparison in the low 80% LTV they are around 40%. Device protection and online backup for the top 20% LTV are around 55%, in comparison to only around 22% in the low LTV. As a company we would like to sell to customers streaming TV and movies and also online backup and device protection if we want to increase LTV.

# %% [markdown]
# ## 3. For those who churned what is the proportion of each kind of contract?

# %%
# Under 80 (percentage)
total_charges_under80.Contract.value_counts() / total_charges_under80.shape[0]
# Out:
# Month-to-month    0.959197
# One year          0.036789
# Two year          0.004013
# Name: Contract, dtype: float64

# %%
# Above 80 (percentage)
total_charges_above80.Contract.value_counts() / total_charges_above80.shape[0]
# Out:
# Month-to-month    0.590909
# One year          0.296791
# Two year          0.112299
# Name: Contract, dtype: float64

# %% [markdown]
# ## 4. For those who did not churn what is the proportion of each kind of contract?

# %%
## Extract those who unsubscribed the services (Churn = Yes)

paying_df = pd.read_sql("select * from churn_all where Churn = 'No'", conn)

# %%
paying_df.TotalCharges.describe()
# Out:
# count    5163.000000
# mean     2555.344141
# std      2329.456984
# min        18.800000
# 25%       577.825000
# 50%      1683.600000
# 75%      4264.125000
# max      8672.450000
# Name: TotalCharges, dtype: float64

# %%
# Find the 80th percentile of the data in TotalCharges
paying_df.TotalCharges.quantile(0.8)
# Out:
# 4895.850000000001

# %%
# Divide the data by the 80th percentile of the data from the TotalCharges variable
paying_total_charges_under80 = paying_df.query("TotalCharges <= 4895.8")
paying_total_charges_above80 = paying_df.query("TotalCharges > 4895.8")

# %%
# Under 80 (percentage)
paying_total_charges_under80.Contract.value_counts() / paying_total_charges_under80.shape[0]
# Out:
# Month-to-month    0.500726
# Two year          0.253269
# One year          0.246005
# Name: Contract, dtype: float64

# %%
# Above 80 (percentage)
paying_total_charges_above80.Contract.value_counts() / paying_total_charges_above80.shape[0]
# Out:
# Two year          0.572120
# One year          0.280736
# Month-to-month    0.147144
# Name: Contract, dtype: float64

# %% [markdown]
# - If we want to stop Churning we would like to sell contracts to people for at least one year, and much better for 2 years (Conjecture).
# - We have 57% of the people that stayed in the company in the top 20% LTV with 2 year contracts, and only 11% of the people in the top 20% had a 2 year contract and left the company.
# - 95% of the people that left the company and are in the low 80% have a month-to-month contract, in contrast to only 50% of the people in the low 80% that stayed in the company. We can say that having a month-to-month contract is one of the reasons that people are leaving the company (conjecture).
