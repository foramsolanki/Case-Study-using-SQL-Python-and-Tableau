# %% [markdown]
# # Churn case. Part 1.

# %%
import pandas as pd

# %% [markdown]
# ## Reading all CSV files with Pandas

# %%
customer = pd.read_csv("customer.csv")
customer.head()
# Out:
#    CustomerID  Gender SeniorCitizen Partner Dependents
# 0  3668-QPYBK    Male            No      No         No
# 1  9237-HQITU  Female            No      No        Yes
# 2  9305-CDSKC  Female            No      No        Yes
# 3  7892-POOKP  Female            No     Yes        Yes
# 4  0280-XJGEX    Male            No      No        Yes

# %%
cust_loc = pd.read_csv("cust_loc.csv")
cust_loc.head()
# Out:
#       Cust_ID       State   Latitude   Longitude  ZipCode
# 0  3668-QPYBK  California  33.964131 -118.272783    90003
# 1  9237-HQITU  California  34.059281 -118.307420    90005
# 2  9305-CDSKC  California  34.048013 -118.293953    90006
# 3  7892-POOKP  California  34.062125 -118.315709    90010
# 4  0280-XJGEX  California  34.039224 -118.266293    90015

# %%
cust_services = pd.read_csv("cust_services.csv")
cust_services.head()
# Out:
#       Cust_ID PhoneService MultipleLines InternetService OnlineSecurity  \
# 0  3668-QPYBK          Yes            No             DSL            Yes
# 1  9237-HQITU          Yes            No     Fiber optic             No
# 2  9305-CDSKC          Yes           Yes     Fiber optic             No
# 3  7892-POOKP          Yes           Yes     Fiber optic             No
# 4  0280-XJGEX          Yes           Yes     Fiber optic             No
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0          Yes               No          No          No              No
# 1           No               No          No          No              No
# 2           No              Yes          No         Yes             Yes
# 3           No              Yes         Yes         Yes             Yes
# 4          Yes              Yes          No         Yes             Yes

# %%
cust_account = pd.read_csv("cust_account.csv")
cust_account.head()
# Out:
#    Account_id  Tenure        Contract              PaymentMethod  \
# 0  3668-QPYBK       2  Month-to-month               Mailed check
# 1  9237-HQITU       2  Month-to-month           Electronic check
# 2  9305-CDSKC       8  Month-to-month           Electronic check
# 3  7892-POOKP      28  Month-to-month           Electronic check
# 4  0280-XJGEX      49  Month-to-month  Bank transfer (automatic)
#
#   PaperlessBilling  MonthlyCharges TotalCharges
# 0              Yes           53.85       108.15
# 1              Yes           70.70       151.65
# 2              Yes           99.65        820.5
# 3              Yes          104.80      3046.05
# 4              Yes          103.70       5036.3

# %%
cust_account.dtypes
# Out:
# Account_id           object
# Tenure                int64
# Contract             object
# PaymentMethod        object
# PaperlessBilling     object
# MonthlyCharges      float64
# TotalCharges         object
# dtype: object

# %%
cust_churn = pd.read_csv("cust_churn.csv")
cust_churn.head()
# Out:
#            Id Churn
# 0  3668-QPYBK   Yes
# 1  9237-HQITU   Yes
# 2  9305-CDSKC   Yes
# 3  7892-POOKP   Yes
# 4  0280-XJGEX   Yes

# %% [markdown]
# ## Create database and tables

# %%
import sqlite3

# %%
conn = sqlite3.connect("churn.db")
cur = conn.cursor()

# %%
# Create customer table
customer.to_sql("customer", conn, if_exists="replace", index=False)

# %%
# Create customer location table
cust_loc.to_sql("cust_loc", conn, if_exists="replace", index=False)

# %%
# Create customer services table
cust_services.to_sql("cust_services", conn, if_exists="replace", index=False)

# %%
# Create customer accountcust_account table
cust_account.to_sql("cust_account", conn, if_exists="replace", index=False)

# %%
# Create customer churn table
cust_churn.to_sql("cust_churn", conn, if_exists="replace", index=False)

# %% [markdown]
# ## Information about our tables

# %%
def table_info(conn,cursor):
    """
    prints out all of the columns of every table in the DB
    
    conn: database connection object
    cursor: cursor object
    """
    
    tables = cur.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()
    for table_name in tables:
        table_name = table_name[0]
        table = pd.read_sql_query("SELECT * from {} LIMIT 0".format(table_name), conn)
        print(table_name)
        for col in table.columns:
            print("\t "+ col)
            print()

# %%
table_info(conn,cur)
# Out:
# customer
# 	 CustomerID
#
# 	 Gender
#
# 	 SeniorCitizen
#
# 	 Partner
#
# 	 Dependents
#
# cust_loc
# 	 Cust_ID
#
# 	 State
#
# 	 Latitude
#
# 	 Longitude
#
# 	 ZipCode
#
# cust_services
# 	 Cust_ID
#
# 	 PhoneService
#
# 	 MultipleLines
#
# 	 InternetService
#
# 	 OnlineSecurity
#
# 	 OnlineBackup
#
# 	 DeviceProtection
#
# 	 TechSupport
#
# 	 StreamingTV
#
# 	 StreamingMovies
#
# cust_account
# 	 Account_id
#
# 	 Tenure
#
# 	 Contract
#
# 	 PaymentMethod
#
# 	 PaperlessBilling
#
# 	 MonthlyCharges
#
# 	 TotalCharges
#
# cust_churn
# 	 Id
#
# 	 Churn

# %% [markdown]
# ## Join all tables

# %%
cur.execute(
"""
ALTER TABLE cust_loc
RENAME COLUMN Cust_ID TO CustomerID;
""")

# %%
table_info(conn,cur)
# Out:
# customer
# 	 CustomerID
#
# 	 Gender
#
# 	 SeniorCitizen
#
# 	 Partner
#
# 	 Dependents
#
# cust_loc
# 	 CustomerID
#
# 	 State
#
# 	 Latitude
#
# 	 Longitude
#
# 	 ZipCode
#
# cust_services
# 	 Cust_ID
#
# 	 PhoneService
#
# 	 MultipleLines
#
# 	 InternetService
#
# 	 OnlineSecurity
#
# 	 OnlineBackup
#
# 	 DeviceProtection
#
# 	 TechSupport
#
# 	 StreamingTV
#
# 	 StreamingMovies
#
# cust_account
# 	 Account_id
#
# 	 Tenure
#
# 	 Contract
#
# 	 PaymentMethod
#
# 	 PaperlessBilling
#
# 	 MonthlyCharges
#
# 	 TotalCharges
#
# cust_churn
# 	 Id
#
# 	 Churn

# %%
cur.execute(
"""
SELECT 
*
FROM customer
INNER JOIN cust_loc
USING (CustomerID)
""")
cur.fetchone()
# Out:
# ('3668-QPYBK',
#  'Male',
#  'No',
#  'No',
#  'No',
#  'California',
#  33.964131,
#  -118.272783,
#  90003)

# %%
cust_loc = cust_loc.rename(columns={"Cust_ID": "CustomerID"})

# %%
cust_loc.head()
# Out:
#    CustomerID       State   Latitude   Longitude  ZipCode
# 0  3668-QPYBK  California  33.964131 -118.272783    90003
# 1  9237-HQITU  California  34.059281 -118.307420    90005
# 2  9305-CDSKC  California  34.048013 -118.293953    90006
# 3  7892-POOKP  California  34.062125 -118.315709    90010
# 4  0280-XJGEX  California  34.039224 -118.266293    90015

# %%
pd.concat([customer,cust_loc], join="inner", axis=1)
# Out:
#       CustomerID  Gender SeniorCitizen Partner Dependents  CustomerID  \
# 0     3668-QPYBK    Male            No      No         No  3668-QPYBK
# 1     9237-HQITU  Female            No      No        Yes  9237-HQITU
# 2     9305-CDSKC  Female            No      No        Yes  9305-CDSKC
# 3     7892-POOKP  Female            No     Yes        Yes  7892-POOKP
# 4     0280-XJGEX    Male            No      No        Yes  0280-XJGEX
# 5     4190-MFLUW  Female            No     Yes         No  4190-MFLUW
# 6     8779-QRDMV    Male           Yes      No         No  8779-QRDMV
# 7     1066-JKSGK    Male            No      No         No  1066-JKSGK
# 8     6467-CHFZW    Male            No     Yes        Yes  6467-CHFZW
# 9     8665-UTDHZ    Male            No     Yes         No  8665-UTDHZ
# 10    8773-HHUOZ  Female            No      No         No  8773-HHUOZ
# 11    6047-YHPVI    Male            No      No        Yes  6047-YHPVI
# 12    5380-WJKOV    Male            No      No        Yes  5380-WJKOV
# 13    8168-UQWWF  Female            No      No        Yes  8168-UQWWF
# 14    7760-OYPDY  Female            No      No        Yes  7760-OYPDY
# 15    9420-LOJKX  Female            No      No        Yes  9420-LOJKX
# 16    7495-OOKFY  Female           Yes     Yes        Yes  7495-OOKFY
# 17    1658-BYGOY    Male           Yes      No        Yes  1658-BYGOY
# 18    5698-BQJOH  Female            No      No        Yes  5698-BQJOH
# 19    5919-TMRGD  Female            No      No        Yes  5919-TMRGD
# 20    9191-MYQKX  Female            No     Yes        Yes  9191-MYQKX
# 21    8637-XJIVR  Female            No      No        Yes  8637-XJIVR
# 22    0278-YXOOG    Male            No      No         No  0278-YXOOG
# 23    4598-XLKNJ  Female           Yes     Yes        Yes  4598-XLKNJ
# 24    3192-NQECA    Male            No     Yes         No  3192-NQECA
# 25    0486-HECZI    Male            No     Yes        Yes  0486-HECZI
# 26    4846-WHAFZ  Female           Yes     Yes        Yes  4846-WHAFZ
# 27    5299-RULOA  Female            No     Yes        Yes  5299-RULOA
# 28    0404-SWRVG    Male            No      No        Yes  0404-SWRVG
# 29    4412-YLTKF  Female           Yes      No        Yes  4412-YLTKF
# ...          ...     ...           ...     ...        ...         ...
# 7013  9586-JGQKH  Female            No     Yes         No  9586-JGQKH
# 7014  4501-VCPFK    Male            No      No         No  4501-VCPFK
# 7015  6075-SLNIL    Male            No      No         No  6075-SLNIL
# 7016  9347-AERRL    Male            No     Yes         No  9347-AERRL
# 7017  2274-XUATA    Male           Yes     Yes         No  2274-XUATA
# 7018  6691-CCIHA  Female            No     Yes         No  6691-CCIHA
# 7019  1685-BQULA  Female            No      No         No  1685-BQULA
# 7020  9053-EJUNL    Male            No      No         No  9053-EJUNL
# 7021  0666-UXTJO    Male           Yes     Yes         No  0666-UXTJO
# 7022  1471-GIQKQ  Female            No      No         No  1471-GIQKQ
# 7023  4807-IZYOZ  Female            No      No         No  4807-IZYOZ
# 7024  9710-NJERN  Female            No      No         No  9710-NJERN
# 7025  9837-FWLCH    Male            No     Yes        Yes  9837-FWLCH
# 7026  7203-OYKCT    Male            No      No         No  7203-OYKCT
# 7027  1035-IPQPU  Female           Yes     Yes         No  1035-IPQPU
# 7028  7398-LXGYX    Male            No     Yes         No  7398-LXGYX
# 7029  2823-LKABH  Female            No      No         No  2823-LKABH
# 7030  0550-DCXLH    Male            No      No         No  0550-DCXLH
# 7031  9281-CEDRU  Female            No     Yes         No  9281-CEDRU
# 7032  2235-DWLJU  Female           Yes      No         No  2235-DWLJU
# 7033  0871-OPBXW  Female            No      No         No  0871-OPBXW
# 7034  3605-JISKB    Male           Yes     Yes         No  3605-JISKB
# 7035  9767-FFLEM    Male            No      No         No  9767-FFLEM
# 7036  8456-QDAVC    Male            No      No         No  8456-QDAVC
# 7037  7750-EYXWZ  Female            No      No         No  7750-EYXWZ
# 7038  2569-WGERO  Female            No      No         No  2569-WGERO
# 7039  6840-RESVB    Male            No     Yes        Yes  6840-RESVB
# 7040  2234-XADUH  Female            No     Yes        Yes  2234-XADUH
# 7041  4801-JZAZL  Female            No     Yes        Yes  4801-JZAZL
# 7042  3186-AJIEK    Male            No      No         No  3186-AJIEK
#
#            State   Latitude   Longitude  ZipCode
# 0     California  33.964131 -118.272783    90003
# 1     California  34.059281 -118.307420    90005
# 2     California  34.048013 -118.293953    90006
# 3     California  34.062125 -118.315709    90010
# 4     California  34.039224 -118.266293    90015
# 5     California  34.066367 -118.309868    90020
# 6     California  34.023810 -118.156582    90022
# 7     California  34.066303 -118.435479    90024
# 8     California  34.099869 -118.326843    90028
# 9     California  34.089953 -118.294824    90029
# 10    California  34.078821 -118.177576    90032
# 11    California  34.110845 -118.259595    90039
# 12    California  34.137412 -118.207607    90041
# 13    California  34.115720 -118.192754    90042
# 14    California  33.987945 -118.370442    90056
# 15    California  33.921280 -118.274186    90061
# 16    California  34.044271 -118.185237    90063
# 17    California  34.108833 -118.229715    90065
# 18    California  34.063947 -118.383001    90211
# 19    California  33.978030 -118.217141    90255
# 20    California  33.923573 -118.200669    90262
# 21    California  33.977468 -118.445475    90292
# 22    California  33.956445 -118.358634    90301
# 23    California  33.936291 -118.332639    90303
# 24    California  34.031529 -118.491156    90403
# 25    California  33.867257 -118.330794    90504
# 26    California  33.972119 -118.020188    90602
# 27    California  33.976678 -118.065875    90606
# 28    California  33.940619 -117.951300    90631
# 29    California  33.989524 -118.089299    90660
# ...          ...        ...         ...      ...
# 7013  California  33.829583 -116.474131    92234
# 7014  California  33.680031 -116.171678    92236
# 7015  California  33.889605 -115.257009    92239
# 7016  California  33.948558 -116.516976    92240
# 7017  California  34.137742 -114.365140    92242
# 7018  California  34.167236 -116.281511    92252
# 7019  California  33.695532 -116.310571    92253
# 7020  California  33.543835 -115.993906    92254
# 7021  California  34.097863 -116.594561    92256
# 7022  California  33.345825 -115.596574    92257
# 7023  California  33.906496 -116.569499    92258
# 7024  California  33.694501 -116.412711    92260
# 7025  California  33.839989 -116.659215    92262
# 7026  California  33.324900 -114.758334    92266
# 7027  California  34.273872 -114.192901    92267
# 7028  California  34.201108 -116.593456    92268
# 7029  California  33.763678 -116.429928    92270
# 7030  California  33.536040 -116.119222    92274
# 7031  California  33.281560 -115.955541    92275
# 7032  California  33.849263 -116.382778    92276
# 7033  California  34.172110 -115.769773    92277
# 7034  California  34.457829 -116.139589    92278
# 7035  California  33.036790 -115.605030    92281
# 7036  California  32.852947 -114.850784    92283
# 7037  California  34.159534 -116.425984    92284
# 7038  California  34.341737 -116.539416    92285
# 7039  California  34.667815 -117.536183    92301
# 7040  California  34.559882 -115.637164    92304
# 7041  California  34.167800 -116.864330    92305
# 7042  California  34.424926 -117.184503    92308
#
# [7043 rows x 10 columns]

# %%
# Rename remaining columns from tables
cust_services = cust_services.rename(columns={"Cust_ID": "CustomerID"})
cust_account = cust_account.rename(columns={"Account_id": "CustomerID"})
cust_churn = cust_churn.rename(columns={"Id": "CustomerID"})

# %%
dfs_to_join = [customer, cust_loc, cust_services, cust_account, cust_churn]

# %%
customer.loc[customer["Gender"] == "Male",]
# Out:
#       CustomerID Gender SeniorCitizen Partner Dependents
# 0     3668-QPYBK   Male            No      No         No
# 4     0280-XJGEX   Male            No      No        Yes
# 6     8779-QRDMV   Male           Yes      No         No
# 7     1066-JKSGK   Male            No      No         No
# 8     6467-CHFZW   Male            No     Yes        Yes
# 9     8665-UTDHZ   Male            No     Yes         No
# 11    6047-YHPVI   Male            No      No        Yes
# 12    5380-WJKOV   Male            No      No        Yes
# 17    1658-BYGOY   Male           Yes      No        Yes
# 22    0278-YXOOG   Male            No      No         No
# 24    3192-NQECA   Male            No     Yes         No
# 25    0486-HECZI   Male            No     Yes        Yes
# 28    0404-SWRVG   Male            No      No        Yes
# 31    3091-FYHKI   Male            No      No         No
# 32    2372-HWUHI   Male            No      No         No
# 35    2135-RXIHG   Male            No      No         No
# 36    3874-EQOEP   Male            No      No        Yes
# 39    3445-HXXGF   Male           Yes     Yes         No
# 45    9367-WXLCH   Male            No      No        Yes
# 48    2472-OVKUP   Male            No     Yes        Yes
# 49    1285-OKIPP   Male            No      No        Yes
# 51    7841-TZDMQ   Male            No      No         No
# 53    0742-MOABM   Male            No     Yes         No
# 55    8937-RDTHP   Male            No      No        Yes
# 56    1251-KRREG   Male            No      No         No
# 58    9947-OTFQU   Male           Yes      No         No
# 59    0322-YINQP   Male            No      No         No
# 61    9514-JDSKI   Male           Yes     Yes         No
# 63    7273-TEFQD   Male           Yes      No         No
# 64    3606-TWKGI   Male           Yes      No         No
# ...          ...    ...           ...     ...        ...
# 6975  2898-MRKPI   Male            No     Yes        Yes
# 6977  3648-GZPHF   Male            No     Yes        Yes
# 6979  9588-YRFHY   Male            No      No         No
# 6980  9364-YKUVW   Male            No      No         No
# 6982  2451-YMUXS   Male           Yes      No         No
# 6983  3914-FDRHP   Male            No      No         No
# 6987  9547-ITEFG   Male            No     Yes        Yes
# 6990  6598-KELSS   Male            No      No        Yes
# 6995  2843-CQMEG   Male            No      No         No
# 6997  5351-QESIO   Male            No      No        Yes
# 7001  6447-GORXK   Male            No      No        Yes
# 7002  6967-PEJLL   Male            No     Yes        Yes
# 7006  0376-OIWME   Male            No     Yes         No
# 7007  0218-QNVAS   Male            No     Yes        Yes
# 7009  7164-BPTUT   Male            No      No        Yes
# 7014  4501-VCPFK   Male            No      No         No
# 7015  6075-SLNIL   Male            No      No         No
# 7016  9347-AERRL   Male            No     Yes         No
# 7017  2274-XUATA   Male           Yes     Yes         No
# 7020  9053-EJUNL   Male            No      No         No
# 7021  0666-UXTJO   Male           Yes     Yes         No
# 7025  9837-FWLCH   Male            No     Yes        Yes
# 7026  7203-OYKCT   Male            No      No         No
# 7028  7398-LXGYX   Male            No     Yes         No
# 7030  0550-DCXLH   Male            No      No         No
# 7034  3605-JISKB   Male           Yes     Yes         No
# 7035  9767-FFLEM   Male            No      No         No
# 7036  8456-QDAVC   Male            No      No         No
# 7039  6840-RESVB   Male            No     Yes        Yes
# 7042  3186-AJIEK   Male            No      No         No
#
# [3555 rows x 5 columns]

# %%
churn_all = pd.concat(dfs_to_join, join="inner", axis=1)

# %%
churn_all = churn_all.loc[:, ~churn_all.columns.duplicated()]

# %%
churn_all.head()
# Out:
#    CustomerID  Gender SeniorCitizen Partner Dependents       State   Latitude  \
# 0  3668-QPYBK    Male            No      No         No  California  33.964131
# 1  9237-HQITU  Female            No      No        Yes  California  34.059281
# 2  9305-CDSKC  Female            No      No        Yes  California  34.048013
# 3  7892-POOKP  Female            No     Yes        Yes  California  34.062125
# 4  0280-XJGEX    Male            No      No        Yes  California  34.039224
#
#     Longitude  ZipCode PhoneService  ... TechSupport StreamingTV  \
# 0 -118.272783    90003          Yes  ...          No          No
# 1 -118.307420    90005          Yes  ...          No          No
# 2 -118.293953    90006          Yes  ...          No         Yes
# 3 -118.315709    90010          Yes  ...         Yes         Yes
# 4 -118.266293    90015          Yes  ...          No         Yes
#
#   StreamingMovies Tenure        Contract              PaymentMethod  \
# 0              No      2  Month-to-month               Mailed check
# 1              No      2  Month-to-month           Electronic check
# 2             Yes      8  Month-to-month           Electronic check
# 3             Yes     28  Month-to-month           Electronic check
# 4             Yes     49  Month-to-month  Bank transfer (automatic)
#
#   PaperlessBilling MonthlyCharges  TotalCharges Churn
# 0              Yes          53.85        108.15   Yes
# 1              Yes          70.70        151.65   Yes
# 2              Yes          99.65         820.5   Yes
# 3              Yes         104.80       3046.05   Yes
# 4              Yes         103.70        5036.3   Yes
#
# [5 rows x 25 columns]

# %%
churn_all.dtypes
# Out:
# CustomerID           object
# Gender               object
# SeniorCitizen        object
# Partner              object
# Dependents           object
# State                object
# Latitude            float64
# Longitude           float64
# ZipCode               int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Tenure                int64
# Contract             object
# PaymentMethod        object
# PaperlessBilling     object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
churn_all["TotalCharges"] = pd.to_numeric(churn_all["TotalCharges"], errors="coerce")

# %%
churn_all.dtypes
# Out:
# CustomerID           object
# Gender               object
# SeniorCitizen        object
# Partner              object
# Dependents           object
# State                object
# Latitude            float64
# Longitude           float64
# ZipCode               int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Tenure                int64
# Contract             object
# PaymentMethod        object
# PaperlessBilling     object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
# Missing values
churn_all.isnull().sum(axis=0)
# Out:
# CustomerID           0
# Gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# State                0
# Latitude             0
# Longitude            0
# ZipCode              0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Tenure               0
# Contract             0
# PaymentMethod        0
# PaperlessBilling     0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# Drop the missing values
churn_all = churn_all.dropna()

# %%
churn_all.isnull().sum(axis=0)
# Out:
# CustomerID          0
# Gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# State               0
# Latitude            0
# Longitude           0
# ZipCode             0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Tenure              0
# Contract            0
# PaymentMethod       0
# PaperlessBilling    0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
churn_all.dtypes
# Out:
# CustomerID           object
# Gender               object
# SeniorCitizen        object
# Partner              object
# Dependents           object
# State                object
# Latitude            float64
# Longitude           float64
# ZipCode               int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Tenure                int64
# Contract             object
# PaymentMethod        object
# PaperlessBilling     object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
churn_all.to_sql("churn_all", conn, if_exists="replace", index=False)

# %%
cur.execute("PRAGMA table_info('churn_all')").fetchall()
# Out:
# [(0, 'CustomerID', 'TEXT', 0, None, 0),
#  (1, 'Gender', 'TEXT', 0, None, 0),
#  (2, 'SeniorCitizen', 'TEXT', 0, None, 0),
#  (3, 'Partner', 'TEXT', 0, None, 0),
#  (4, 'Dependents', 'TEXT', 0, None, 0),
#  (5, 'State', 'TEXT', 0, None, 0),
#  (6, 'Latitude', 'REAL', 0, None, 0),
#  (7, 'Longitude', 'REAL', 0, None, 0),
#  (8, 'ZipCode', 'INTEGER', 0, None, 0),
#  (9, 'PhoneService', 'TEXT', 0, None, 0),
#  (10, 'MultipleLines', 'TEXT', 0, None, 0),
#  (11, 'InternetService', 'TEXT', 0, None, 0),
#  (12, 'OnlineSecurity', 'TEXT', 0, None, 0),
#  (13, 'OnlineBackup', 'TEXT', 0, None, 0),
#  (14, 'DeviceProtection', 'TEXT', 0, None, 0),
#  (15, 'TechSupport', 'TEXT', 0, None, 0),
#  (16, 'StreamingTV', 'TEXT', 0, None, 0),
#  (17, 'StreamingMovies', 'TEXT', 0, None, 0),
#  (18, 'Tenure', 'INTEGER', 0, None, 0),
#  (19, 'Contract', 'TEXT', 0, None, 0),
#  (20, 'PaymentMethod', 'TEXT', 0, None, 0),
#  (21, 'PaperlessBilling', 'TEXT', 0, None, 0),
#  (22, 'MonthlyCharges', 'REAL', 0, None, 0),
#  (23, 'TotalCharges', 'REAL', 0, None, 0),
#  (24, 'Churn', 'TEXT', 0, None, 0)]

# %%
pd.read_sql("select * from churn_all", conn)
# Out:
#       CustomerID  Gender SeniorCitizen Partner Dependents       State  \
# 0     3668-QPYBK    Male            No      No         No  California
# 1     9237-HQITU  Female            No      No        Yes  California
# 2     9305-CDSKC  Female            No      No        Yes  California
# 3     7892-POOKP  Female            No     Yes        Yes  California
# 4     0280-XJGEX    Male            No      No        Yes  California
# 5     4190-MFLUW  Female            No     Yes         No  California
# 6     8779-QRDMV    Male           Yes      No         No  California
# 7     1066-JKSGK    Male            No      No         No  California
# 8     6467-CHFZW    Male            No     Yes        Yes  California
# 9     8665-UTDHZ    Male            No     Yes         No  California
# 10    8773-HHUOZ  Female            No      No         No  California
# 11    6047-YHPVI    Male            No      No        Yes  California
# 12    5380-WJKOV    Male            No      No        Yes  California
# 13    8168-UQWWF  Female            No      No        Yes  California
# 14    7760-OYPDY  Female            No      No        Yes  California
# 15    9420-LOJKX  Female            No      No        Yes  California
# 16    7495-OOKFY  Female           Yes     Yes        Yes  California
# 17    1658-BYGOY    Male           Yes      No        Yes  California
# 18    5698-BQJOH  Female            No      No        Yes  California
# 19    5919-TMRGD  Female            No      No        Yes  California
# 20    9191-MYQKX  Female            No     Yes        Yes  California
# 21    8637-XJIVR  Female            No      No        Yes  California
# 22    0278-YXOOG    Male            No      No         No  California
# 23    4598-XLKNJ  Female           Yes     Yes        Yes  California
# 24    3192-NQECA    Male            No     Yes         No  California
# 25    0486-HECZI    Male            No     Yes        Yes  California
# 26    4846-WHAFZ  Female           Yes     Yes        Yes  California
# 27    5299-RULOA  Female            No     Yes        Yes  California
# 28    0404-SWRVG    Male            No      No        Yes  California
# 29    4412-YLTKF  Female           Yes      No        Yes  California
# ...          ...     ...           ...     ...        ...         ...
# 7002  9586-JGQKH  Female            No     Yes         No  California
# 7003  4501-VCPFK    Male            No      No         No  California
# 7004  6075-SLNIL    Male            No      No         No  California
# 7005  9347-AERRL    Male            No     Yes         No  California
# 7006  2274-XUATA    Male           Yes     Yes         No  California
# 7007  6691-CCIHA  Female            No     Yes         No  California
# 7008  1685-BQULA  Female            No      No         No  California
# 7009  9053-EJUNL    Male            No      No         No  California
# 7010  0666-UXTJO    Male           Yes     Yes         No  California
# 7011  1471-GIQKQ  Female            No      No         No  California
# 7012  4807-IZYOZ  Female            No      No         No  California
# 7013  9710-NJERN  Female            No      No         No  California
# 7014  9837-FWLCH    Male            No     Yes        Yes  California
# 7015  7203-OYKCT    Male            No      No         No  California
# 7016  1035-IPQPU  Female           Yes     Yes         No  California
# 7017  7398-LXGYX    Male            No     Yes         No  California
# 7018  2823-LKABH  Female            No      No         No  California
# 7019  0550-DCXLH    Male            No      No         No  California
# 7020  9281-CEDRU  Female            No     Yes         No  California
# 7021  2235-DWLJU  Female           Yes      No         No  California
# 7022  0871-OPBXW  Female            No      No         No  California
# 7023  3605-JISKB    Male           Yes     Yes         No  California
# 7024  9767-FFLEM    Male            No      No         No  California
# 7025  8456-QDAVC    Male            No      No         No  California
# 7026  7750-EYXWZ  Female            No      No         No  California
# 7027  2569-WGERO  Female            No      No         No  California
# 7028  6840-RESVB    Male            No     Yes        Yes  California
# 7029  2234-XADUH  Female            No     Yes        Yes  California
# 7030  4801-JZAZL  Female            No     Yes        Yes  California
# 7031  3186-AJIEK    Male            No      No         No  California
#
#        Latitude   Longitude  ZipCode PhoneService  ...          TechSupport  \
# 0     33.964131 -118.272783    90003          Yes  ...                   No
# 1     34.059281 -118.307420    90005          Yes  ...                   No
# 2     34.048013 -118.293953    90006          Yes  ...                   No
# 3     34.062125 -118.315709    90010          Yes  ...                  Yes
# 4     34.039224 -118.266293    90015          Yes  ...                   No
# 5     34.066367 -118.309868    90020          Yes  ...                  Yes
# 6     34.023810 -118.156582    90022           No  ...                   No
# 7     34.066303 -118.435479    90024          Yes  ...  No internet service
# 8     34.099869 -118.326843    90028          Yes  ...                   No
# 9     34.089953 -118.294824    90029           No  ...                   No
# 10    34.078821 -118.177576    90032          Yes  ...                   No
# 11    34.110845 -118.259595    90039          Yes  ...                   No
# 12    34.137412 -118.207607    90041          Yes  ...                   No
# 13    34.115720 -118.192754    90042          Yes  ...                   No
# 14    33.987945 -118.370442    90056          Yes  ...                   No
# 15    33.921280 -118.274186    90061          Yes  ...                   No
# 16    34.044271 -118.185237    90063          Yes  ...                   No
# 17    34.108833 -118.229715    90065          Yes  ...                   No
# 18    34.063947 -118.383001    90211          Yes  ...                   No
# 19    33.978030 -118.217141    90255          Yes  ...                   No
# 20    33.923573 -118.200669    90262          Yes  ...                   No
# 21    33.977468 -118.445475    90292          Yes  ...                   No
# 22    33.956445 -118.358634    90301          Yes  ...  No internet service
# 23    33.936291 -118.332639    90303          Yes  ...                   No
# 24    34.031529 -118.491156    90403          Yes  ...                  Yes
# 25    33.867257 -118.330794    90504          Yes  ...                   No
# 26    33.972119 -118.020188    90602          Yes  ...                   No
# 27    33.976678 -118.065875    90606          Yes  ...                   No
# 28    33.940619 -117.951300    90631          Yes  ...                   No
# 29    33.989524 -118.089299    90660          Yes  ...                   No
# ...         ...         ...      ...          ...  ...                  ...
# 7002  33.829583 -116.474131    92234          Yes  ...                  Yes
# 7003  33.680031 -116.171678    92236           No  ...                  Yes
# 7004  33.889605 -115.257009    92239          Yes  ...                   No
# 7005  33.948558 -116.516976    92240          Yes  ...  No internet service
# 7006  34.137742 -114.365140    92242           No  ...                  Yes
# 7007  34.167236 -116.281511    92252          Yes  ...                  Yes
# 7008  33.695532 -116.310571    92253          Yes  ...                   No
# 7009  33.543835 -115.993906    92254          Yes  ...                   No
# 7010  34.097863 -116.594561    92256          Yes  ...                   No
# 7011  33.345825 -115.596574    92257          Yes  ...                   No
# 7012  33.906496 -116.569499    92258          Yes  ...  No internet service
# 7013  33.694501 -116.412711    92260          Yes  ...  No internet service
# 7014  33.839989 -116.659215    92262          Yes  ...  No internet service
# 7015  33.324900 -114.758334    92266          Yes  ...                   No
# 7016  34.273872 -114.192901    92267          Yes  ...                   No
# 7017  34.201108 -116.593456    92268          Yes  ...                   No
# 7018  33.763678 -116.429928    92270          Yes  ...                  Yes
# 7019  33.536040 -116.119222    92274          Yes  ...                  Yes
# 7020  33.281560 -115.955541    92275          Yes  ...                  Yes
# 7021  33.849263 -116.382778    92276           No  ...                   No
# 7022  34.172110 -115.769773    92277          Yes  ...  No internet service
# 7023  34.457829 -116.139589    92278          Yes  ...                   No
# 7024  33.036790 -115.605030    92281          Yes  ...                   No
# 7025  32.852947 -114.850784    92283          Yes  ...                   No
# 7026  34.159534 -116.425984    92284           No  ...                  Yes
# 7027  34.341737 -116.539416    92285          Yes  ...  No internet service
# 7028  34.667815 -117.536183    92301          Yes  ...                  Yes
# 7029  34.559882 -115.637164    92304          Yes  ...                   No
# 7030  34.167800 -116.864330    92305           No  ...                   No
# 7031  34.424926 -117.184503    92308          Yes  ...                  Yes
#
#               StreamingTV      StreamingMovies Tenure        Contract  \
# 0                      No                   No      2  Month-to-month
# 1                      No                   No      2  Month-to-month
# 2                     Yes                  Yes      8  Month-to-month
# 3                     Yes                  Yes     28  Month-to-month
# 4                     Yes                  Yes     49  Month-to-month
# 5                      No                   No     10  Month-to-month
# 6                      No                  Yes      1  Month-to-month
# 7     No internet service  No internet service      1  Month-to-month
# 8                     Yes                  Yes     47  Month-to-month
# 9                      No                   No      1  Month-to-month
# 10                    Yes                  Yes     17  Month-to-month
# 11                     No                   No      5  Month-to-month
# 12                    Yes                  Yes     34  Month-to-month
# 13                    Yes                  Yes     11  Month-to-month
# 14                    Yes                   No      2  Month-to-month
# 15                    Yes                  Yes     15  Month-to-month
# 16                     No                   No      8  Month-to-month
# 17                    Yes                  Yes     18  Month-to-month
# 18                    Yes                  Yes      9  Month-to-month
# 19                    Yes                   No      1  Month-to-month
# 20                     No                   No      7  Month-to-month
# 21                     No                   No     12  Month-to-month
# 22    No internet service  No internet service      5  Month-to-month
# 23                    Yes                  Yes     25  Month-to-month
# 24                    Yes                  Yes     68        Two year
# 25                    Yes                   No     55  Month-to-month
# 26                     No                   No     37  Month-to-month
# 27                    Yes                  Yes     10  Month-to-month
# 28                     No                   No      3  Month-to-month
# 29                     No                   No     27  Month-to-month
# ...                   ...                  ...    ...             ...
# 7002                  Yes                  Yes     64        Two year
# 7003                   No                   No     26  Month-to-month
# 7004                   No                  Yes     38  Month-to-month
# 7005  No internet service  No internet service     23        One year
# 7006                  Yes                  Yes     72        Two year
# 7007                  Yes                  Yes     62        Two year
# 7008                  Yes                   No     40  Month-to-month
# 7009                  Yes                   No     41  Month-to-month
# 7010                  Yes                   No     34  Month-to-month
# 7011                   No                   No      1  Month-to-month
# 7012  No internet service  No internet service     51        Two year
# 7013  No internet service  No internet service     39        Two year
# 7014  No internet service  No internet service     12  Month-to-month
# 7015                  Yes                  Yes     72        One year
# 7016                  Yes                  Yes     63  Month-to-month
# 7017                   No                   No     44  Month-to-month
# 7018                   No                  Yes     18  Month-to-month
# 7019                  Yes                  Yes     13  Month-to-month
# 7020                  Yes                   No     68        Two year
# 7021                  Yes                  Yes      6  Month-to-month
# 7022  No internet service  No internet service      2  Month-to-month
# 7023                   No                   No     55        One year
# 7024                   No                   No     38  Month-to-month
# 7025                  Yes                   No     19  Month-to-month
# 7026                  Yes                  Yes     12        One year
# 7027  No internet service  No internet service     72        Two year
# 7028                  Yes                  Yes     24        One year
# 7029                  Yes                  Yes     72        One year
# 7030                   No                   No     11  Month-to-month
# 7031                  Yes                  Yes     66        Two year
#
#                   PaymentMethod PaperlessBilling MonthlyCharges  TotalCharges  \
# 0                  Mailed check              Yes          53.85        108.15
# 1              Electronic check              Yes          70.70        151.65
# 2              Electronic check              Yes          99.65        820.50
# 3              Electronic check              Yes         104.80       3046.05
# 4     Bank transfer (automatic)              Yes         103.70       5036.30
# 5       Credit card (automatic)               No          55.20        528.35
# 6              Electronic check              Yes          39.65         39.65
# 7                  Mailed check               No          20.15         20.15
# 8              Electronic check              Yes          99.35       4749.15
# 9              Electronic check               No          30.20         30.20
# 10                 Mailed check              Yes          64.70       1093.10
# 11             Electronic check              Yes          69.70        316.90
# 12             Electronic check              Yes         106.35       3549.25
# 13    Bank transfer (automatic)              Yes          97.85       1105.40
# 14             Electronic check              Yes          80.65        144.15
# 15      Credit card (automatic)              Yes          99.10       1426.40
# 16      Credit card (automatic)              Yes          80.65        633.30
# 17             Electronic check              Yes          95.45       1752.55
# 18             Electronic check               No          94.40        857.25
# 19             Electronic check              Yes          79.35         79.35
# 20    Bank transfer (automatic)              Yes          75.15        496.90
# 21             Electronic check              Yes          78.95        927.35
# 22                 Mailed check               No          21.05        113.85
# 23             Electronic check              Yes          98.50       2514.50
# 24    Bank transfer (automatic)              Yes         110.00       7611.85
# 25             Electronic check              Yes          96.75       5238.90
# 26             Electronic check              Yes          76.50       2868.15
# 27             Electronic check              Yes         100.25       1064.65
# 28             Electronic check              Yes          74.40        229.55
# 29             Electronic check              Yes          78.05       2135.50
# ...                         ...              ...            ...           ...
# 7002  Bank transfer (automatic)              Yes         105.40       6794.75
# 7003           Electronic check               No          35.75       1022.50
# 7004    Credit card (automatic)              Yes          95.10       3691.20
# 7005    Credit card (automatic)               No          19.30        486.20
# 7006  Bank transfer (automatic)              Yes          63.10       4685.55
# 7007           Electronic check              Yes          84.95       5150.55
# 7008  Bank transfer (automatic)              Yes          93.40       3756.40
# 7009           Electronic check              Yes          89.20       3645.75
# 7010    Credit card (automatic)              Yes          85.20       2874.45
# 7011           Electronic check               No          49.95         49.95
# 7012  Bank transfer (automatic)               No          20.65       1020.75
# 7013               Mailed check               No          20.15        826.00
# 7014           Electronic check              Yes          19.20        239.00
# 7015           Electronic check              Yes         104.95       7544.30
# 7016           Electronic check              Yes         103.50       6479.40
# 7017    Credit card (automatic)              Yes          84.80       3626.35
# 7018  Bank transfer (automatic)              Yes          95.05       1679.40
# 7019               Mailed check               No          73.35        931.55
# 7020  Bank transfer (automatic)               No          64.10       4326.25
# 7021           Electronic check              Yes          44.40        263.05
# 7022               Mailed check              Yes          20.05         39.25
# 7023    Credit card (automatic)               No          60.00       3316.10
# 7024    Credit card (automatic)              Yes          69.50       2625.25
# 7025  Bank transfer (automatic)              Yes          78.70       1495.10
# 7026           Electronic check               No          60.65        743.30
# 7027  Bank transfer (automatic)              Yes          21.15       1419.40
# 7028               Mailed check              Yes          84.80       1990.50
# 7029    Credit card (automatic)              Yes         103.20       7362.90
# 7030           Electronic check              Yes          29.60        346.45
# 7031  Bank transfer (automatic)              Yes         105.65       6844.50
#
#      Churn
# 0      Yes
# 1      Yes
# 2      Yes
# 3      Yes
# 4      Yes
# 5      Yes
# 6      Yes
# 7      Yes
# 8      Yes
# 9      Yes
# 10     Yes
# 11     Yes
# 12     Yes
# 13     Yes
# 14     Yes
# 15     Yes
# 16     Yes
# 17     Yes
# 18     Yes
# 19     Yes
# 20     Yes
# 21     Yes
# 22     Yes
# 23     Yes
# 24     Yes
# 25     Yes
# 26     Yes
# 27     Yes
# 28     Yes
# 29     Yes
# ...    ...
# 7002    No
# 7003    No
# 7004    No
# 7005    No
# 7006    No
# 7007    No
# 7008    No
# 7009    No
# 7010    No
# 7011    No
# 7012    No
# 7013    No
# 7014    No
# 7015    No
# 7016    No
# 7017    No
# 7018    No
# 7019    No
# 7020    No
# 7021    No
# 7022    No
# 7023    No
# 7024    No
# 7025    No
# 7026    No
# 7027    No
# 7028    No
# 7029    No
# 7030    No
# 7031    No
#
# [7032 rows x 25 columns]

# %% [markdown]
# ## See all tables

# %%
cur.execute("select name from sqlite_master where type='table'")
cur.fetchall()
# Out:
# [('customer',),
#  ('cust_loc',),
#  ('cust_services',),
#  ('cust_account',),
#  ('cust_churn',),
#  ('churn_all',)]
